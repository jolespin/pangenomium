# %%
import pandas as pd 
import numpy as np

# %%
protein_to_ortholog__veba = pd.read_csv("results/veba-cluster_output/output/proteins_to_orthogroups.tsv", sep="\t", index_col=0, header=None).squeeze()
# protein_to_ortholog__pangenomium = "P" + pd.read_csv("results/pangenomium_output/output/proteins_to_orthologs.tsv.gz", sep="\t", index_col=0, header=None).squeeze().map(lambda x: x.replace("__","_"))
protein_to_ortholog__pangenomium = pd.read_csv("results/pangenomium_output/output/proteins_to_orthologs.tsv.gz", sep="\t", index_col=0, header=None).squeeze()


np.all(protein_to_ortholog__pangenomium.loc[protein_to_ortholog__veba.index] == protein_to_ortholog__veba)
# Out:
# True

# %%
protein_to_ortholog__pangenomium
# Out:
# 0
# H|S1|C1393773_1    PSLC-6c20a3569965cfd39c938950ff564d84_SSPC-002...
# H|S1|C460139_1     PSLC-6c20a3569965cfd39c938950ff564d84_SSPC-002...
# H|S1|C97943_1      PSLC-6c20a3569965cfd39c938950ff564d84_SSPC-003...
# H|S1|C1101037_2    PSLC-6c20a3569965cfd39c938950ff564d84_SSPC-003...
# H|S1|C1348551_1    PSLC-6c20a3569965cfd39c938950ff564d84_SSPC-003...
#                                          ...
# H|S5|C458196_1     PSLC-1718f8aa823d796075b6d336f41c62ea_SSPC-ffe...
# H|S5|C723097_6     PSLC-1718f8aa823d796075b6d336f41c62ea_SSPC-ffe...
# H|S5|C672783_2     PSLC-1718f8aa823d796075b6d336f41c62ea_SSPC-fff...
# H|S5|C429029_5     PSLC-1718f8aa823d796075b6d336f41c62ea_SSPC-fff...
# H|S5|C565151_5     PSLC-1718f8aa823d796075b6d336f41c62ea_SSPC-fff...
# Name: 1, Length: 149788, dtype: object
